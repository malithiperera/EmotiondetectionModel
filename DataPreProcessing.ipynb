# %% [markdown]
# <a href="https://colab.research.google.com/github/malithiperera/EmotiondetectionModel/blob/master/DataPreProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip /content/drive/MyDrive/dataset/DAiSEE.zip -d /content/drive/MyDrive/dataset/extracted

# %%
data_path = '/content/drive/My Drive/dataset/extracted/DAiSEE/Labels/TrainLabels.csv'

# %%
import pandas as pd

df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#            ClipID  Boredom  Engagement  Confusion  Frustration
# 0  1100011002.avi        0           2          0             0
# 1  1100011003.avi        0           2          0             0
# 2  1100011004.avi        0           3          0             0
# 3  1100011005.avi        0           3          0             0
# 4  1100011006.avi        0           3          0             0

# %%
df_new=df.copy()

# %%
df_new.drop(labels=['Engagement','Confusion'],axis=1,inplace=True)
df_new.head()
# Out:
#            ClipID  Boredom  Frustration
# 0  1100011002.avi        0             0
# 1  1100011003.avi        0             0
# 2  1100011004.avi        0             0
# 3  1100011005.avi        0             0
# 4  1100011006.avi        0             0

# %%
df_new.rename(columns={"Frustration ":"Frustration"},inplace=True)

# %%
df_new['Boredom'] = df_new['Boredom'].replace({0: 0, 1: 1, 2: 1, 3: 1})
df_new['Frustration'] = df_new['Frustration'].replace({0: 0, 1: 1, 2: 1, 3: 1})

# %%
df_new.head()
# Out:
#            ClipID  Boredom  Frustration
# 0  1100011002.avi        0            0
# 1  1100011003.avi        0            0
# 2  1100011004.avi        0            0
# 3  1100011005.avi        0            0
# 4  1100011006.avi        0            0
